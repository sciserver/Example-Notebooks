# %%
from SciServer import CasJobs

# %%
CasJobs.executeQuery('select * from DecompSample', context='EarthSciTest')
# Out:
#       DecompSampleID  PlotID  TeabagID          DeploymentDate  \
# 0                  1       1       341   11/5/2013 12:00:00 AM
# 1                  2       1       937   11/5/2013 12:00:00 AM
# 2                  3       1      1331   11/5/2013 12:00:00 AM
# 3                  4       1      1334   11/5/2013 12:00:00 AM
# 4                  5       1      1429   11/5/2013 12:00:00 AM
# 5                  6       1       550   11/5/2013 12:00:00 AM
# 6                  7       1       836   11/5/2013 12:00:00 AM
# 7                  8       1      1357   11/5/2013 12:00:00 AM
# 8                  9       1      1406   11/5/2013 12:00:00 AM
# 9                 10       1      1437   11/5/2013 12:00:00 AM
# 10                11       1      1035   11/5/2013 12:00:00 AM
# 11                12       1      1299   11/5/2013 12:00:00 AM
# 12                13       1      1348   11/5/2013 12:00:00 AM
# 13                14       1      1351   11/5/2013 12:00:00 AM
# ...
